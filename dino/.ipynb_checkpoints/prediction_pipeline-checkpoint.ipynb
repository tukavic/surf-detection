# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-1.21.0.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 10.8 MB/s eta 0:00:01
# Collecting Flask>=1.0.4
#   Downloading Flask-2.0.1-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 9.0 MB/s  eta 0:00:01
# Collecting flask-compress
#   Downloading Flask_Compress-1.10.1-py3-none-any.whl (7.9 kB)
# Collecting plotly
#   Downloading plotly-5.1.0-py2.py3-none-any.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 18.9 MB/s eta 0:00:01
# Collecting dash-core-components==1.17.1
#   Downloading dash_core_components-1.17.1.tar.gz (3.7 MB)
#      |████████████████████████████████| 3.7 MB 73.6 MB/s eta 0:00:01
# Collecting dash-html-components==1.1.4
#   Downloading dash_html_components-1.1.4.tar.gz (83 kB)
#      |████████████████████████████████| 83 kB 8.7 MB/s  eta 0:00:01
# Collecting dash-table==4.12.0
#   Downloading dash_table-4.12.0.tar.gz (1.8 MB)
#      |████████████████████████████████| 1.8 MB 63.2 MB/s eta 0:00:01
# Requirement already satisfied: future in /home/lathomas5/miniconda3/lib/python3.8/site-packages (from dash) (0.18.2)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Requirement already satisfied: click>=7.1.2 in /home/lathomas5/miniconda3/lib/python3.8/site-packages (from Flask>=1.0.4->dash) (7.1.2)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 66.7 MB/s eta 0:00:01
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 69.9 MB/s eta 0:00:01
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 72.0 MB/s eta 0:00:01
# Requirement already satisfied: six in /home/lathomas5/miniconda3/lib/python3.8/site-packages (from plotly->dash) (1.15.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux2010_x86_64.whl (30 kB)
# Building wheels for collected packages: dash, dash-core-components, dash-html-components, dash-table
#   Building wheel for dash (setup.py) ... done
#   Created wheel for dash: filename=dash-1.21.0-py3-none-any.whl size=1100478 sha256=45de602b5951df365df74c85f2fb16ddef97913cc5a99b1618cffd3f1eeda38b
#   Stored in directory: /home/lathomas5/.cache/pip/wheels/56/e4/21/8a1190a7c31f3aa3f8834b05126ded8bf105b8fd11fad1806e
#   Building wheel for dash-core-components (setup.py) ... done
#   Created wheel for dash-core-components: filename=dash_core_components-1.17.1-py3-none-any.whl size=3738983 sha256=269be746fe32ff0e1f248a3b71837e39a4490f4d8637b4dd43cef4c130b6c03e
#   Stored in directory: /home/lathomas5/.cache/pip/wheels/08/ae/6a/0f4a0ee8fa216ebf1f2e57277693a20d80e8a2cfe549f66d86
#   Building wheel for dash-html-components (setup.py) ... done
#   Created wheel for dash-html-components: filename=dash_html_components-1.1.4-py3-none-any.whl size=319753 sha256=3e293d0a5480eda1d41ca30572cccafe8cd7dbb3f9545607258d03d6299cf9bd
#   Stored in directory: /home/lathomas5/.cache/pip/wheels/12/fe/5a/d0f2f657ee34cef5cc3fced1d8992994fac1ca6232a03c6c03
#   Building wheel for dash-table (setup.py) ... done
#   Created wheel for dash-table: filename=dash_table-4.12.0-py3-none-any.whl size=1837667 sha256=2cefd5bfb538b303995c10d2770a6db389b4257e676f6ac1e0c1b4e85f997257
#   Stored in directory: /home/lathomas5/.cache/pip/wheels/81/20/78/23b49f61328cc14ddb5542b7a232a23c80891a9115fcd159d6
# Successfully built dash dash-core-components dash-html-components dash-table
# Installing collected packages: itsdangerous, MarkupSafe, Jinja2, Werkzeug, Flask, brotli, flask-compress, tenacity, plotly, dash-core-components, dash-html-components, dash-table, dash
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.2
#     Uninstalling Jinja2-2.11.2:
#       Successfully uninstalled Jinja2-2.11.2
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
# Successfully installed Flask-2.0.1 Jinja2-3.0.1 MarkupSafe-2.0.1 Werkzeug-2.0.1 brotli-1.0.9 dash-1.21.0 dash-core-components-1.17.1 dash-html-components-1.1.4 dash-table-4.12.0 flask-compress-1.10.1 itsdangerous-2.0.1 plotly-5.1.0 tenacity-8.0.1

# %%
import os

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage.feature import blob_dog, blob_doh, blob_log

import torch
from torch import nn
from torchvision import transforms as pth_transforms

from PIL import Image

import vision_transformer as vits

os.environ['KMP_DUPLICATE_LIB_OK']='TRUE'
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# <ipython-input-5-6d6dcbdbaeee> in <module>
#      13 from PIL import Image
#      14
# ---> 15 import vision_transformer as vits
#      16
#      17 os.environ['KMP_DUPLICATE_LIB_OK']='TRUE'
#
# ~/surf-detection/dino/vision_transformer.py in <module>
#      22 import torch.nn as nn
#      23
# ---> 24 from utils import trunc_normal_
#      25
#      26
#
# ~/surf-detection/dino/utils.py in <module>
#     817 import json
#     818
# --> 819 import dash_core_components as dcc
#     820 import plotly.graph_objs as go
#     821 import dash_reusable_components as drc
#
# ~/miniconda3/lib/python3.8/site-packages/dash_core_components/__init__.py in <module>
#       4 import os as _os
#       5 import sys as _sys
# ----> 6 import dash as _dash
#       7
#       8 _basepath = _os.path.dirname(__file__)
#
# ~/miniconda3/lib/python3.8/site-packages/dash/__init__.py in <module>
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from . import dependencies  # noqa: F401,E402
#       7 from . import development  # noqa: F401,E402
#
# ~/miniconda3/lib/python3.8/site-packages/dash/dash.py in <module>
#      51 from . import _watch
#      52
# ---> 53 _flask_compress_version = parse_version(get_distribution("flask-compress").version)
#      54
#      55 # Add explicit mapping for map files
#
# ~/miniconda3/lib/python3.8/site-packages/pkg_resources/__init__.py in get_distribution(dist)
#     463         dist = Requirement.parse(dist)
#     464     if isinstance(dist, Requirement):
# --> 465         dist = get_provider(dist)
#     466     if not isinstance(dist, Distribution):
#     467         raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# ~/miniconda3/lib/python3.8/site-packages/pkg_resources/__init__.py in get_provider(moduleOrReq)
#     339     """Return an IResourceProvider for the named module or requirement"""
#     340     if isinstance(moduleOrReq, Requirement):
# --> 341         return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     342     try:
#     343         module = sys.modules[moduleOrReq]
#
# ~/miniconda3/lib/python3.8/site-packages/pkg_resources/__init__.py in require(self, *requirements)
#     882         included, even if they were already activated in this working set.
#     883         """
# --> 884         needed = self.resolve(parse_requirements(requirements))
#     885
#     886         for dist in needed:
#
# ~/miniconda3/lib/python3.8/site-packages/pkg_resources/__init__.py in resolve(self, requirements, env, installer, replace_conflicting, extras)
#     773                 # Oops, the "best" so far conflicts with a dependency
#     774                 dependent_req = required_by[req]
# --> 775                 raise VersionConflict(dist, req).with_context(dependent_req)
#     776
#     777             # push the new requirements onto the stack
#
# ContextualVersionConflict: (Jinja2 2.11.2 (/home/lathomas5/miniconda3/lib/python3.8/site-packages), Requirement.parse('Jinja2>=3.0'), {'flask'})

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('jacks5to8.csv', index_col=0)
df.time = pd.to_datetime(df.time)
df = df[:5]
df
# Out:
#                                       filename                      time
# 0  ./data/images/2021-07-12 07:35:03-07:00.png 2021-07-12 07:35:03-07:00
# 1  ./data/images/2021-07-12 07:36:03-07:00.png 2021-07-12 07:36:03-07:00
# 2  ./data/images/2021-07-12 07:37:03-07:00.png 2021-07-12 07:37:03-07:00
# 3  ./data/images/2021-07-12 07:38:03-07:00.png 2021-07-12 07:38:03-07:00
# 4  ./data/images/2021-07-12 07:39:03-07:00.png 2021-07-12 07:39:03-07:00

# %% [markdown]
# ## Load model

# %%
arch = 'vit_small'
patch_size = 8
pretrained_weights = 'vit_small'
checkpoint_key = None
image_path = './data/images/'

# image_size = (592, 1184)
output_dir = '.'
threshold = None

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
# build model
model = vits.__dict__[arch](patch_size=patch_size, num_classes=0)
for p in model.parameters():
    p.requires_grad = False
model.eval()
model.to(device)
if os.path.isfile(pretrained_weights):
    state_dict = torch.load(pretrained_weights, map_location="cpu")
    if checkpoint_key is not None and checkpoint_key in state_dict:
        print(f"Take key {checkpoint_key} in provided checkpoint dict")
        state_dict = state_dict[checkpoint_key]
    # remove `module.` prefix
    state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    # remove `backbone.` prefix induced by multicrop wrapper
    state_dict = {k.replace("backbone.", ""): v for k, v in state_dict.items()}
    msg = model.load_state_dict(state_dict, strict=False)
    print('Pretrained weights found at {} and loaded with msg: {}'.format(pretrained_weights, msg))
else:
    print("Please use the `--pretrained_weights` argument to indicate the path of the checkpoint to evaluate.")
    url = None
    if arch == "vit_small" and patch_size == 16:
        url = "dino_deitsmall16_pretrain/dino_deitsmall16_pretrain.pth"
    elif arch == "vit_small" and patch_size == 8:
        url = "dino_deitsmall8_300ep_pretrain/dino_deitsmall8_300ep_pretrain.pth"  # model used for visualizations in our paper
    elif arch == "vit_base" and patch_size == 16:
        url = "dino_vitbase16_pretrain/dino_vitbase16_pretrain.pth"
    elif arch == "vit_base" and patch_size == 8:
        url = "dino_vitbase8_pretrain/dino_vitbase8_pretrain.pth"
    if url is not None:
        print("Since no pretrained weights have been provided, we load the reference pretrained DINO weights.")
        state_dict = torch.hub.load_state_dict_from_url(url="https://dl.fbaipublicfiles.com/dino/" + url)
        model.load_state_dict(state_dict, strict=True)
    else:
        print("There is no reference weights available for this model => We use random weights.")
# Out:
# Please use the `--pretrained_weights` argument to indicate the path of the checkpoint to evaluate.
# Since no pretrained weights have been provided, we load the reference pretrained DINO weights.

# %%
def load_image(file, image_size = (592, 1184)):
    '''loads picture and applies torch transforms'''
    img = Image.open(file)
    img = img.convert('RGB')
    
    transform = pth_transforms.Compose([
        pth_transforms.Resize(image_size),
        pth_transforms.ToTensor(),
        pth_transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
    ])
    img = transform(img)
    
    return img

# %%
def patch_image(img, patch_size):
    '''Reshapes image to be divisible by the patch size'''
    w, h = img.shape[1] - img.shape[1] % patch_size, img.shape[2] - img.shape[2] % patch_size
    img = img[:, :w, :h].unsqueeze(0)

    w_featmap = img.shape[-2] // patch_size
    h_featmap = img.shape[-1] // patch_size
    
    return img, w_featmap, h_featmap

# %%
def mask_image(img, patch_size):
    '''Passes image through model and returns attention mask'''
    img, w_featmap, h_featmap = patch_image(img, patch_size)
    print(img.shape)
    attentions = model.get_last_selfattention(img.to(device))
    print(attentions.shape)
    nh = attentions.shape[1] # number of head

    # we keep only the output patch attention
    heatmap = attentions[0, :, 0, 1:].reshape(nh, -1)
    heatmap = heatmap.reshape(nh, w_featmap, h_featmap)
    
    # interpolate attention mask back to original image size
    heatmap = nn.functional.interpolate(heatmap.unsqueeze(0), scale_factor=patch_size, mode="nearest")[0].cpu().numpy()
    
    return heatmap.sum(0).astype('double')

# %%
def get_blobs(heatimg):
    '''
    predicts the number of surfers as the number of 
    blobs found in the attention mask of an image
    '''
    blobs = blob_doh(heatimg*256, threshold=0.05, min_sigma = 10, max_sigma=50)
    
    return blobs

# %%
def predict(row, patch_size=8):
    # img = load_img(row['filename'], image_size)
    img = load_image(row['filename'])
    print(img.shape)
    heatimg = mask_image(img, patch_size)
    blobs = get_blobs(heatimg)
    num_blobs = len(blobs)
    # row['pred_num_surfers'] = num_blobs
    
    return num_blobs, blobs, img, heatimg
n, blobs, img, heatimg = predict(df.iloc[0], patch_size = patch_size)
print(n)
# Out:
# torch.Size([3, 592, 1184])
# torch.Size([1, 3, 592, 1184])
# torch.Size([1, 6, 10953, 10953])
# 15

# %%
df.iloc[0].filename
# Out:
# './data/images/2021-07-12 07:35:03-07:00.png'

# %%
# n, img, heatimg = predict(df.iloc[0], patch_size = patch_size)

print(n)
plt.imshow(heatimg)
plt.scatter(blobs[:, 1], blobs[:, 0], c='white')
plt.show()
# Out:
# 15

# %%
# Get predictions for each image like this?
df = df.apply(lambda row: predict(row), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bde79bcd7f66> in <module>
#       1 # Get predictions for each image like this?
# ----> 2 df = df.apply(lambda row: predict(row), axis=1)
#
# NameError: name 'df' is not defined
